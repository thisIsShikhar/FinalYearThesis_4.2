# %%
from skimage.restoration import denoise_nl_means, estimate_sigma
from skimage import img_as_ubyte, img_as_float
from matplotlib import pyplot as plt
from skimage import io
import numpy as np
import cv2

from sklearn.metrics import mean_squared_error
img =(cv2.imread("test/CNV-163081-6.jpeg"))

# %%
sigma_est = np.mean(estimate_sigma(img, multichannel=True))

patch_kw = dict(patch_size=5,      
                patch_distance=3,  
                multichannel=True)

denoise_img = denoise_nl_means(img, h=1.15 * sigma_est, fast_mode=True,
                               patch_size=6, patch_distance=50, multichannel=True)
"""
denoise_img = denoise_nl_means(img, h=1.15 * sigma_est, fast_mode=False,
                           **patch_kw)
"""
denoise_img_as_8byte = img_as_ubyte(denoise_img)

plt.imshow(denoise_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c84ff2518720> in <module>
# ----> 1 sigma_est = np.mean(estimate_sigma(img, multichannel=True))
#       2
#       3 patch_kw = dict(patch_size=5,
#       4                 patch_distance=3,
#       5                 multichannel=True)
#
# ~/anaconda3/lib/python3.8/site-packages/skimage/restoration/_denoise.py in estimate_sigma(image, average_sigmas, multichannel)
#     920     """
#     921     if multichannel:
# --> 922         nchannels = image.shape[-1]
#     923         sigmas = [estimate_sigma(
#     924             image[..., c], multichannel=False) for c in range(nchannels)]
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(img)
